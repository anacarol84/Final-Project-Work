# %%
#Import libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
import seaborn as sns


# machine learning sklearn
from sklearn import linear_model 
from sklearn import metrics
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA, ARMAResults
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from statsmodels) (1.3.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from packaging>=21.3->statsmodels) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\ana_c\anaconda3\envs\pythondata\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
global_temps = pd.read_csv("GlobalLandTemperaturesByState.csv", sep=',')

# convert first column to DateTime format|
global_temps['dt'] = pd.to_datetime(global_temps['dt'])

global_temps.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0 1855-05-01              25.544                          1.171  Acre  Brazil
# 1 1855-06-01              24.228                          1.103  Acre  Brazil
# 2 1855-07-01              24.371                          1.044  Acre  Brazil
# 3 1855-08-01              25.427                          1.073  Acre  Brazil
# 4 1855-09-01              25.675                          1.014  Acre  Brazil

# %%
#Transform date into year

global_temps_column = global_temps['dt'].dt.year
global_temps_column
# Out:
# 0         1855
# 1         1855
# 2         1855
# 3         1855
# 4         1855
#           ...
# 645670    2013
# 645671    2013
# 645672    2013
# 645673    2013
# 645674    2013
# Name: dt, Length: 645675, dtype: int64

# %%
#rename country column to country name

global_temp_new = global_temps.rename(columns = {"Country": "Country Name"})
global_temp_new.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty State  \
# 0 1855-05-01              25.544                          1.171  Acre
# 1 1855-06-01              24.228                          1.103  Acre
# 2 1855-07-01              24.371                          1.044  Acre
# 3 1855-08-01              25.427                          1.073  Acre
# 4 1855-09-01              25.675                          1.014  Acre
#
#   Country Name
# 0       Brazil
# 1       Brazil
# 2       Brazil
# 3       Brazil
# 4       Brazil

# %%
#Adding the date into the Dataframe

global_temp_new['Year'] = global_temps_column
global_temp_new.head(1260)
# Out:
#              dt  AverageTemperature  AverageTemperatureUncertainty State  \
# 0    1855-05-01              25.544                          1.171  Acre
# 1    1855-06-01              24.228                          1.103  Acre
# 2    1855-07-01              24.371                          1.044  Acre
# 3    1855-08-01              25.427                          1.073  Acre
# 4    1855-09-01              25.675                          1.014  Acre
# ...         ...                 ...                            ...   ...
# 1255 1959-12-01              26.187                          0.215  Acre
# 1256 1960-01-01              26.454                          0.337  Acre
# 1257 1960-02-01              26.157                          0.445  Acre
# 1258 1960-03-01              26.418                          0.316  Acre
# 1259 1960-04-01              25.393                          0.298  Acre
#
#      Country Name  Year
# 0          Brazil  1855
# 1          Brazil  1855
# 2          Brazil  1855
# 3          Brazil  1855
# 4          Brazil  1855
# ...           ...   ...
# 1255       Brazil  1959
# 1256       Brazil  1960
# 1257       Brazil  1960
# 1258       Brazil  1960
# 1259       Brazil  1960
#
# [1260 rows x 6 columns]

# %%
global_temp_new['Year'] = global_temp_new['Year'].apply(str)

# %%
#rename country column to country name

# global_temp_new = global_temps.rename({"Country": "Country Name"})
# global_temp_new.head()

# %%
global_temp_new["Country Name"].value_counts()
# Out:
# Russia           254972
# United States    149745
# India             86664
# China             68506
# Canada            35358
# Brazil            34328
# Australia         16102
# Name: Country Name, dtype: int64

# %%
#Read the Co2 file

Co2_emmission = pd.read_csv("API_EN.ATM.CO2E.PC_DS2_en_csv_v2_3638608.csv", skiprows=4)
                        
Co2_emmission.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code      1960      1961  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC       NaN       NaN
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.906060  0.922474
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057  0.053589
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.090880  0.095283
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835  0.082204
#
#        1962      1963      1964      1965  ...      2012      2013      2014  \
# 0       NaN       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 1  0.930816  0.940570  0.996033  1.047280  ...  1.021646  1.031833  1.041145
# 2  0.073721  0.074161  0.086174  0.101285  ...  0.335351  0.263716  0.234037
# 3  0.096612  0.112376  0.133258  0.184803  ...  0.490867  0.504655  0.507671
# 4  0.210533  0.202739  0.213562  0.205891  ...  1.204799  1.261542  1.285365
#
#        2015      2016      2017      2018  2019  2020  Unnamed: 65
# 0       NaN       NaN       NaN       NaN   NaN   NaN          NaN
# 1  0.987393  0.971016  0.959978  0.933541   NaN   NaN          NaN
# 2  0.232176  0.208857  0.203328  0.200151   NaN   NaN          NaN
# 3  0.480743  0.472959  0.476438  0.515544   NaN   NaN          NaN
# 4  1.260921  1.227703  1.034317  0.887380   NaN   NaN          NaN
#
# [5 rows x 66 columns]

# %%
#Drop unecessary columns

Co2_emmission.drop(columns=["Indicator Name","Indicator Code", "Country Code","Unnamed: 65"], inplace=True)

# %%
# for c in Co2_emmission["Country Name"].unique():
#     if c in global_temps['Country'].unique():
#         print(c)

# %%
#Check what countries are in both files

Countries = [ c for c in Co2_emmission["Country Name"].unique() if c in global_temps['Country'].unique()]

# %%
Countries
# Out:
# ['Australia', 'Brazil', 'Canada', 'China', 'India', 'United States']

# %%
new_rows_for_co2_dataframe = []

for col in Co2_emmission.columns[1:]:
    for i, row in Co2_emmission.iterrows():
        temp = pd.DataFrame({
            "Country": [row["Country Name"]],
            "Year": [col],
            "CO2": [row[col]]
        })
        new_rows_for_co2_dataframe.append(temp)

co2_df = pd.concat(new_rows_for_co2_dataframe)

# %%
co2_df
# Out:
#                         Country  Year       CO2
# 0                         Aruba  1960       NaN
# 0   Africa Eastern and Southern  1960  0.906060
# 0                   Afghanistan  1960  0.046057
# 0    Africa Western and Central  1960  0.090880
# 0                        Angola  1960  0.100835
# ..                          ...   ...       ...
# 0                        Kosovo  2020       NaN
# 0                   Yemen, Rep.  2020       NaN
# 0                  South Africa  2020       NaN
# 0                        Zambia  2020       NaN
# 0                      Zimbabwe  2020       NaN
#
# [16226 rows x 3 columns]

# %%
# clean_co2_df = co2_df.loc[co2_df["Country"].isin(["Switzerland","United Kingdom"])]

# %%
# clean_co2_df
# Out:
#            Country  Year        CO2
# 0      Switzerland  1960   3.664366
# 0   United Kingdom  1960  11.150759
# 0      Switzerland  1961   3.751825
# 0   United Kingdom  1961  11.154139
# 0      Switzerland  1962   4.333572
# ..             ...   ...        ...
# 0   United Kingdom  2018   5.398708
# 0      Switzerland  2019        NaN
# 0   United Kingdom  2019        NaN
# 0      Switzerland  2020        NaN
# 0   United Kingdom  2020        NaN
#
# [122 rows x 3 columns]

# %%
co2_df['Year'] = co2_df['Year'].apply(str)

# %%
# clean_global_temp_df = global_temp_new.loc[global_temp_new["Country Name"].isin(["Switzerland"])]

# %%
# clean_global_temp_df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 723662  1743-11-01               3.544                          1.764   Basel
# 723663  1743-12-01                 NaN                            NaN   Basel
# 723664  1744-01-01                 NaN                            NaN   Basel
# 723665  1744-02-01                 NaN                            NaN   Basel
# 723666  1744-03-01                 NaN                            NaN   Basel
# ...            ...                 ...                            ...     ...
# 8592839 2013-05-01               9.400                          0.396  Zurich
# 8592840 2013-06-01              14.444                          0.388  Zurich
# 8592841 2013-07-01              18.658                          0.231  Zurich
# 8592842 2013-08-01              16.657                          0.490  Zurich
# 8592843 2013-09-01                 NaN                            NaN  Zurich
#
#         Country Name Latitude Longitude  Year
# 723662   Switzerland   47.42N     8.29E  1743
# 723663   Switzerland   47.42N     8.29E  1743
# 723664   Switzerland   47.42N     8.29E  1744
# 723665   Switzerland   47.42N     8.29E  1744
# 723666   Switzerland   47.42N     8.29E  1744
# ...              ...      ...       ...   ...
# 8592839  Switzerland   47.42N     8.29E  2013
# 8592840  Switzerland   47.42N     8.29E  2013
# 8592841  Switzerland   47.42N     8.29E  2013
# 8592842  Switzerland   47.42N     8.29E  2013
# 8592843  Switzerland   47.42N     8.29E  2013
#
# [16195 rows x 8 columns]

# %%
Climate_data_merged = pd.merge(global_temp_new, co2_df , how="inner", left_on=["Country Name","Year"],right_on=["Country","Year"])

# %%
Climate_data_merged
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0     1960-01-01              26.454                          0.337
# 1     1960-02-01              26.157                          0.445
# 2     1960-03-01              26.418                          0.316
# 3     1960-04-01              25.393                          0.298
# 4     1960-05-01              24.852                          0.278
# ...          ...                 ...                            ...
# 98035 2013-05-01              19.915                          0.317
# 98036 2013-06-01              16.176                          0.300
# 98037 2013-07-01              15.745                          0.197
# 98038 2013-08-01              18.337                          0.414
# 98039 2013-09-01                 NaN                            NaN
#
#                    State Country Name  Year    Country        CO2
# 0                   Acre       Brazil  1960     Brazil   0.649886
# 1                   Acre       Brazil  1960     Brazil   0.649886
# 2                   Acre       Brazil  1960     Brazil   0.649886
# 3                   Acre       Brazil  1960     Brazil   0.649886
# 4                   Acre       Brazil  1960     Brazil   0.649886
# ...                  ...          ...   ...        ...        ...
# 98035  Western Australia    Australia  2013  Australia  16.398646
# 98036  Western Australia    Australia  2013  Australia  16.398646
# 98037  Western Australia    Australia  2013  Australia  16.398646
# 98038  Western Australia    Australia  2013  Australia  16.398646
# 98039  Western Australia    Australia  2013  Australia  16.398646
#
# [98040 rows x 8 columns]

# %%
Climate_data_merged.to_csv('Climate_change_analysis.csv')
